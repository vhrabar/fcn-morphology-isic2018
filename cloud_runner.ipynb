# %% [markdown]
# # FCN-Based Skin Lesion Segmentation with Morphological Refinement (ISIC2018)
#
# ## Running the main runner in a cloud environment

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/fcn-morphology-isic2018
# !python -m src.main
